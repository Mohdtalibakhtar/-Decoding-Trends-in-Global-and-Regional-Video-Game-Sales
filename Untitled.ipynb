# %%
import pandas as pd

# %%
data = pd.read_csv('game_sales.csv')
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data['Genre'].value_counts()
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Perform label encoding on the 'Genre' column
data['Genre_encoded'] = label_encoder.fit_transform(data['Genre'])

# Display the DataFrame with the encoded 'Genre' column
print(data[['Genre', 'Genre_encoded']])
# Out:
#               Genre  Genre_encoded
# 0            Sports             10
# 1          Platform              4
# 2            Racing              6
# 3            Sports             10
# 4      Role-Playing              7
# ...             ...            ...
# 16593      Platform              4
# 16594       Shooter              8
# 16595        Racing              6
# 16596        Puzzle              5
# 16597      Platform              4
#
# [16598 rows x 2 columns]

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Perform label encoding on the 'Genre' column
data['Publisher_encoded'] = label_encoder.fit_transform(data['Publisher'])

# Display the DataFrame with the encoded 'Genre' column
print(data[['Publisher', 'Publisher_encoded']])
# Out:
#         Publisher  Publisher_encoded
# 0        Nintendo                359
# 1        Nintendo                359
# 2        Nintendo                359
# 3        Nintendo                359
# 4        Nintendo                359
# ...           ...                ...
# 16593       Kemco                269
# 16594  Infogrames                241
# 16595  Activision                 21
# 16596    7G//AMES                  8
# 16597     Wanadoo                546
#
# [16598 rows x 2 columns]

# %%
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Perform label encoding on the 'Genre' column
data['Platform_encoded'] = label_encoder.fit_transform(data['Platform'])

# Display the DataFrame with the encoded 'Genre' column
print(data[['Platform', 'Platform_encoded']])
# Out:
#       Platform  Platform_encoded
# 0          Wii                26
# 1          NES                11
# 2          Wii                26
# 3          Wii                26
# 4           GB                 5
# ...        ...               ...
# 16593      GBA                 6
# 16594       GC                 7
# 16595      PS2                16
# 16596       DS                 4
# 16597      GBA                 6
#
# [16598 rows x 2 columns]

# %%
X = data
X
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
X = data.drop('Name', axis=1)

# %%
cols = ['Platform', 'Publisher', 'Genre']

# %%
X = X.drop(cols, axis=1)

# %%
X
# Out:
#         Rank    Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          1  2006.0     41.49     29.02      3.77         8.46         82.74
# 1          2  1985.0     29.08      3.58      6.81         0.77         40.24
# 2          3  2008.0     15.85     12.88      3.79         3.31         35.82
# 3          4  2009.0     15.75     11.01      3.28         2.96         33.00
# 4          5  1996.0     11.27      8.89     10.22         1.00         31.37
# ...      ...     ...       ...       ...       ...          ...           ...
# 16593  16596  2002.0      0.01      0.00      0.00         0.00          0.01
# 16594  16597  2003.0      0.01      0.00      0.00         0.00          0.01
# 16595  16598  2008.0      0.00      0.00      0.00         0.00          0.01
# 16596  16599  2010.0      0.00      0.01      0.00         0.00          0.01
# 16597  16600  2003.0      0.01      0.00      0.00         0.00          0.01
#
# ...

# %%
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data.isnull().sum()
# Out:
# Rank                 0
# Name                 0
# Platform             0
# Year                 0
# Genre                0
# Publisher            0
# NA_Sales             0
# EU_Sales             0
# JP_Sales             0
# Other_Sales          0
# Global_Sales         0
# Genre_encoded        0
# Publisher_encoded    0
# Platform_encoded     0
# dtype: int64

# %%
mode_value = data['Publisher'].mode()[0]

# Fill missing values with the mode
data['Publisher'].fillna(mode_value, inplace=True)

print(df)
# Out:
#          order_id order_date      status   item_id                    sku  \
# 0       100354678 2020-10-01    received  574772.0     oasis_Oasis-064-36
# 1       100354678 2020-10-01    received  574774.0        Fantastic_FT-48
# 2       100354680 2020-10-01    complete  574777.0        mdeal_DMC-610-8
# 3       100354680 2020-10-01    complete  574779.0     oasis_Oasis-061-36
# 4       100367357 2020-11-13    received  595185.0    MEFNAR59C38B6CA08CD
# ...           ...        ...         ...       ...                    ...
# 286387  100562365 2021-09-30        paid  905179.0    APPCHA5AF14939B8F8A
# 286388  100562376 2021-09-30         cod  905191.0    MEFCOT5A8D1E973B886
# 286389  100562383 2021-09-30         cod  905200.0  WOFVAL59D5EA84167F9-M
# 286390  100562384 2021-09-30         cod  905202.0  WOFNIG5B4D7EB0E9FDD-L
# 286391  100562386 2021-09-30  processing  905205.0    MATHUA5AF70A7D1E50A
#
#         qty_ordered   price   value  discount_amount   total  \
# ...

# %%
mode_value = data['Year'].mode()[0]

# Fill missing values with the mode
data['Year'].fillna(mode_value, inplace=True)
# Out:
#          order_id order_date      status   item_id                    sku  \
# 0       100354678 2020-10-01    received  574772.0     oasis_Oasis-064-36
# 1       100354678 2020-10-01    received  574774.0        Fantastic_FT-48
# 2       100354680 2020-10-01    complete  574777.0        mdeal_DMC-610-8
# 3       100354680 2020-10-01    complete  574779.0     oasis_Oasis-061-36
# 4       100367357 2020-11-13    received  595185.0    MEFNAR59C38B6CA08CD
# ...           ...        ...         ...       ...                    ...
# 286387  100562365 2021-09-30        paid  905179.0    APPCHA5AF14939B8F8A
# 286388  100562376 2021-09-30         cod  905191.0    MEFCOT5A8D1E973B886
# 286389  100562383 2021-09-30         cod  905200.0  WOFVAL59D5EA84167F9-M
# 286390  100562384 2021-09-30         cod  905202.0  WOFNIG5B4D7EB0E9FDD-L
# 286391  100562386 2021-09-30  processing  905205.0    MATHUA5AF70A7D1E50A
#
#         qty_ordered   price   value  discount_amount   total  \
# ...

# %%
game_sales_data = data

# %%
# Global Sales Trends by Year
sales_trends_year = game_sales_data.groupby('Year').sum()['Global_Sales']

# Top Selling Platforms
top_platforms = game_sales_data.groupby('Platform').sum()['Global_Sales'].sort_values(ascending=False).head(10)

# Genre Popularity
genre_popularity = game_sales_data.groupby('Genre').sum()['Global_Sales'].sort_values(ascending=False)

# Regional Sales Comparison
regional_sales = game_sales_data[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum()

# Plotting
plt.figure(figsize=(18, 12))

plt.subplot(2, 2, 1)
sales_trends_year.plot(kind='line', marker='o')
plt.title('Global Sales Trends by Year')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')

plt.subplot(2, 2, 2)
top_platforms.plot(kind='bar')
plt.title('Top Selling Platforms')
plt.xlabel('Platform')
plt.ylabel('Global Sales (in millions)')

plt.subplot(2, 2, 3)
genre_popularity.plot(kind='bar')
plt.title('Genre Popularity')
plt.xlabel('Genre')
plt.ylabel('Global Sales (in millions)')

plt.subplot(2, 2, 4)
regional_sales.plot(kind='bar')
plt.title('Regional Sales Comparison')
plt.xlabel('Region')
plt.ylabel('Sales (in millions)')

plt.tight_layout()
plt.show()

# %%
# Preparing data for Year-wise Genre Popularity Trends
genre_year_sales = game_sales_data.pivot_table(index='Year', columns='Genre', values='Global_Sales', aggfunc='sum')

# Preparing data for Platform vs. Genre Heatmap
platform_genre_sales = game_sales_data.pivot_table(index='Platform', columns='Genre', values='Global_Sales', aggfunc='sum')

# Preparing data for Top Publishers' Market Share Over Time
top_publishers = game_sales_data.groupby('Publisher').sum()['Global_Sales'].sort_values(ascending=False).head(5).index
publisher_year_sales = game_sales_data[game_sales_data['Publisher'].isin(top_publishers)]
publisher_year_sales = publisher_year_sales.pivot_table(index='Year', columns='Publisher', values='Global_Sales', aggfunc='sum')

# Preparing data for Global Sales Distribution for Top Games
top_games = game_sales_data.head(20)  # Top 20 games
top_games['Size'] = top_games['Global_Sales']  # Bubble size based on global sales

# Plotting
plt.figure(figsize=(20, 20))

# Year-wise Genre Popularity Trends
plt.subplot(2, 2, 1)
genre_year_sales.plot(ax=plt.gca())
plt.title('Year-wise Genre Popularity Trends')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')

# Platform vs. Genre Heatmap
plt.subplot(2, 2, 2)
sns.heatmap(platform_genre_sales, cmap='viridis')
plt.title('Platform vs. Genre Heatmap')
plt.xlabel('Genre')
plt.ylabel('Platform')

# Top Publishers' Market Share Over Time
plt.subplot(2, 2, 3)
publisher_year_sales.plot(kind='area', ax=plt.gca(), stacked=True)
plt.title('Top Publishers Market Share Over Time')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')

# Global Sales Distribution for Top Games
plt.subplot(2, 2, 4)
sns.scatterplot(data=top_games, x='Year', y='Global_Sales', size='Size', hue='Name', sizes=(20, 500), legend=False)
plt.title('Global Sales Distribution for Top Games')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/sl/2xmljv516bl9xqlvy5br1fwc0000gn/T/ipykernel_82221/269912028.py:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(14, 8))  
genre_year_sales.plot(ax=plt.gca())
plt.title('Year-wise Genre Popularity Trends')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
# Out:
# Text(0, 0.5, 'Global Sales (in millions)')

# %%
plt.figure(figsize=(14, 8))  

# Preparing data for Global Sales Distribution for Top Games
top_games = game_sales_data.head(20)  # Top 20 games
top_games['Size'] = top_games['Global_Sales']  # Bubble size based on global sales
sns.scatterplot(data=top_games, x='Year', y='Global_Sales', size='Size', hue='Name', sizes=(20, 500), legend=False)
plt.title('Global Sales Distribution for Top Games')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
# Out:
# /var/folders/sl/2xmljv516bl9xqlvy5br1fwc0000gn/T/ipykernel_82221/2329887631.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Text(0, 0.5, 'Global Sales (in millions)')

# %%
# Top Publishers' Market Share Over Time
plt.figure(figsize=(14, 8))  

# Preparing data for Top Publishers' Market Share Over Time
top_publishers = game_sales_data.groupby('Publisher').sum()['Global_Sales'].sort_values(ascending=False).head(5).index
publisher_year_sales = game_sales_data[game_sales_data['Publisher'].isin(top_publishers)]
publisher_year_sales = publisher_year_sales.pivot_table(index='Year', columns='Publisher', values='Global_Sales', aggfunc='sum')

publisher_year_sales.plot(kind='area', ax=plt.gca(), stacked=True)
plt.title('Top Publishers Market Share Over Time')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
# Out:
# Text(0, 0.5, 'Global Sales (in millions)')

# %%
# Global Sales Trends by Year
plt.figure(figsize=(14, 8)) 


sales_trends_year = game_sales_data.groupby('Year').sum()['Global_Sales']

sales_trends_year.plot(kind='line', marker='o')
plt.title('Global Sales Trends by Year')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
# Out:
# Text(0, 0.5, 'Global Sales (in millions)')

# %%
games_sales_data = data

# Selecting a subset of columns for the pair plot
subset_data = game_sales_data[['Global_Sales', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Genre']]

# Creating the pair plot
plt.figure(figsize=(12, 22))
sns.pairplot(subset_data, hue='Genre', diag_kind='hist', plot_kws={'alpha': 0.6, 's': 80, 'edgecolor': 'k'}, height=3)
plt.suptitle('Pairwise Relationships in Video Game Sales Data', size=16)
plt.subplots_adjust(top=0.95)  # Adjusting title position
plt.show()
# Out:
# /Users/mohdtalibakhtar/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
# Preparing data for the stacked bar chart
top_10_games = game_sales_data.nlargest(10, 'Global_Sales')
top_10_sales_regions = top_10_games[['Name', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]

# Plotting
plt.figure(figsize=(12, 8))
top_10_sales_regions.set_index('Name').plot(kind='bar', stacked=True, ax=plt.gca())
plt.title('Top 10 Video Games Sales Distribution Across Regions')
plt.xlabel('Video Game')
plt.ylabel('Sales in Millions')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Region', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Preparing data for the simple bar chart
top_5_games = game_sales_data.nlargest(5, 'Global_Sales')
top_5_sales = top_5_games[['Name', 'Global_Sales']]

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(data=top_5_sales, x='Global_Sales', y='Name')
plt.title('Top 5 Video Games Global Sales')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Video Game')
plt.show()

# %%
# Preparing the correlation matrix
numeric_columns = ['Year', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
correlation_matrix = game_sales_data[numeric_columns].corr()

# Plotting the heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap of Numeric Values')
plt.show()

# %%
data.desc()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sl/2xmljv516bl9xqlvy5br1fwc0000gn/T/ipykernel_82221/3478852496.py in ?()
# ----> 1 data.desc()
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'desc'

# %%
import numpy as np
# Assuming 'df' is your DataFrame
numeric_descriptions = df.describe(include=[np.number])

print(numeric_descriptions)
# Out:
#              item_id    qty_ordered          price          value  \
# count  286392.000000  286392.000000  286392.000000  286392.000000
# mean   741664.902131       3.011296     851.385253     885.879934
# std     95746.031827       4.573837    1741.750751    2073.252179
# min    574769.000000       1.000000       0.000000       0.000000
# 25%    659684.500000       2.000000      49.900000      49.900000
# 50%    742309.000000       2.000000     119.000000     158.970000
# 75%    826124.250000       3.000000     950.000000     910.000000
# max    905208.000000     501.000000  101262.590000  101262.590000
#
#        discount_amount          total        cust_id           year  \
# count    286392.000000  286392.000000  286392.000000  286392.000000
# mean         70.039427     815.840507   70048.019054    2020.618778
# std         256.880870    1983.580302   30243.856395       0.485688
# min           0.000000       0.000000       4.000000    2020.000000
# ...

# %%
# Getting descriptive statistics for numeric columns in the game sales dataset
numeric_descriptions = game_sales_data.describe(include=[np.number])
numeric_descriptions
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.448789      0.264667      0.146652      0.077782
# std     4791.853933      5.790533      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
# Select numeric columns for visualization
numeric_columns = ['Rank', 'Year', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']

# Create a pair plot for numeric columns
sns.set(style="ticks")
sns.pairplot(data[numeric_columns], kind="scatter")

# Set titles and labels
plt.suptitle("Pair Plot of Numeric Columns", size=20)
plt.subplots_adjust(top=0.95)
plt.show()
# Out:
# /Users/mohdtalibakhtar/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
X = data.drop('Global_Sales', axis=1)

X
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
X = X.drop('Global_Sales', axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[185], line 1
# ----> 1 X = X.drop('Global_Sales', axis=1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %%
y = data['Global_Sales']

# %%
from sklearn.model_selection import train_test_split, cross_val_score, learning_curve, GridSearchCV

# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=52)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)
# Out:
# /Users/mohdtalibakhtar/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# SVR()

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error 
# Evaluate the model
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
print(f'R2 Score: {r2:.2f}')
print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
# Out:
# R2 Score: 1.00
# Mean Absolute Error (MAE): 0.00
# Root Mean Squared Error (RMSE): 0.01

# %%
importances = regressor.feature_importances_
feature_names = X.columns
feature_importance_dict = dict(zip(feature_names, importances))
sorted_feature_importance = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)

top_n = 5  # Set the number of top features to display
top_feature_names, top_importances = zip(*sorted_feature_importance[:top_n])

fig = px.bar(
    x=top_importances,
    y=top_feature_names,
    orientation='h',
    title='Top 5 Feature Importance',
    labels={'x': 'Importance', 'y': 'Feature'},
    color=top_importances,  # Color bars by importance values
    color_continuous_scale='reds',  # Choose a color scale
)

fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')

fig.show()
# Out:
# <div>                            <div id="2fa646e2-f9e9-496f-b047-8936232f1aaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fa646e2-f9e9-496f-b047-8936232f1aaf")) {                    Plotly.newPlot(                        "2fa646e2-f9e9-496f-b047-8936232f1aaf",                        [{"alignmentgroup":"True","hovertemplate":"Importance=%{x}<br>Feature=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.9352340106520998,0.03520969527900518,0.023509225969862296,0.005689752245220633,0.00011771827258061218],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"outside","x":[0.9352340106520998,0.03520969527900518,0.023509225969862296,0.0056897
# ...

# %%
›
